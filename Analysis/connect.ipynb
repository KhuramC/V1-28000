# %%
import os
if (os.path.basename(os.getcwd()) !='Model'):
    # %cd ..
    # %cd Model
from bmtool import bmplot
bmplot.connection_matrix(config='config.json',sources='cortex',targets='cortex',synaptic_info="1",sids='pop_name',tids='pop_name')
# Out:
# /home/kac2cf/V1-28000
# /home/kac2cf/V1-28000/Model

# %%
bmplot.connection_matrix(config='config.json',sources='shell',targets='cortex',synaptic_info="1",sids='pop_name',tids='pop_name')
